# %% [markdown]
# # Area plots

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['p', 'q', 'r', 's'])
df.plot(kind='area');

# %%
df.plot(kind='area', stacked=False);

# %% [markdown]
# # Bubble charts

# %%
plt.style.use('ggplot')
df = pd.DataFrame(np.random.rand(50, 3), columns=['a', 'b', 'c'])
df.plot(kind='scatter', x='a', y='b', s=df['c']*400);

# %% [markdown]
# # Hexagon bin plots

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df['b'] = df['b'] + np.arange(1000)
df.plot(kind='hexbin', x='a', y='b', gridsize=20)

# %% [markdown]
# # Trellis plots

# %%
# https://github.com/mwaskom/seaborn

import seaborn as sns
sns.set(style="darkgrid")
 
g = sns.FacetGrid(tips_data, row="sex", col="smoker", margin_titles=True)
bins = np.linspace(0, 60, 13)
g.map(plt.hist, "total_bill", color="steelblue", bins=bins)

# %%
 
'''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-cf9c5bb24048> in <module>()
#      23
#      24
# ---> 25 g.map(plt.hist,  bins=bins)
#      26
#      27 '''
#
# D:\ProgramData\lib\site-packages\seaborn\axisgrid.py in map(self, func, **kwargs)
#    1302                     color = self.palette[k] if kw_color is None else kw_color
#    1303                     func(data_k[x_var], data_k[y_var],
# -> 1304                          label=label_k, color=color, **kwargs)
#    1305
#    1306                 self._clean_axis(ax)
#
# TypeError: hist() got multiple values for argument 'bins'
