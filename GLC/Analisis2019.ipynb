# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Info del set de entrenamiento

# %% [markdown]
#    El set de entrenamiento contará con
#
#    - Informaciones históricas reales y anonimizadas con el flujo de navegación web de nuestros clientes, junto con datos técnicos.
#    - Además, se brindará informacion sobre cuales realizaron una conversión positva para que utilicen como variable dependiente de entrenamiento del modelo predictivo.
#
#    - Luego, tendrán que predecir las nuevas conversiones para el primer trimestre del 2019, indicando los clientes que van a convertir y sobre los que será evaluado su modelo.

# %% [markdown]
# ## Load Categories

# %% [markdown]
#     - Archivos con descripciones textuales de variables categoricas

# %% [markdown]
# #### Content Category

# %%
content_category         = pd.read_csv('./data/CONTENT_CATEGORY.csv')
content_category.head()
# Out:
#                   CONTENT_CATEGORY_descripcion  CONTENT_CATEGORY
# 0                             BANCA:ONLINE:WEB                 1
# 1  NO CATEGORY ASSIGNED > NO CATEGORY ASSIGNED                 2
# 2                      BANCA:ONLINE:WEB:PAGINA                 3
# 3                    NO CATEGORY ASSIGNED > HB                 4
# 4            NO CATEGORY ASSIGNED > HB : ERROR                 5

# %% [markdown]
# #### Content Category Top

# %%
content_category_top     = pd.read_csv('./data/CONTENT_CATEGORY_TOP.csv')
content_category_top.head()
# Out:
#   CONTENT_CATEGORY_TOP_descripcion  CONTENT_CATEGORY_TOP
# 0                 BANCA:ONLINE:WEB                     1
# 1             NO CATEGORY ASSIGNED                     2
# 2             BANCA:ONLINE:WEB:PAG                     3
# 3             BANCA:ONLINE:WEB:PER                     4
# 4             BANCA:ONLINE:WEB:EMI                     5

# %% [markdown]
# #### Content Category Bottom

# %%
content_category_bottom  = pd.read_csv('./data/CONTENT_CATEGORY_BOTTOM.csv')
content_category_bottom.head()
# Out:
#   CONTENT_CATEGORY_BOTTOM_descripcion  CONTENT_CATEGORY_BOTTOM
# 0                    BANCA:ONLINE:WEB                        1
# 1                NO CATEGORY ASSIGNED                        2
# 2             BANCA:ONLINE:WEB:PAGINA                        3
# 3                                  HB                        4
# 4                          HB : ERROR                        5

# %% [markdown]
# ## Load site id

# %%
site_id = pd.read_csv('./data/SITE_ID.csv')
site_id.head()
# Out:
#   SITE_ID_descripcion  SITE_ID
# 0    BANCOGALICIAPROD        1
# 1           MINORISTA        2
# 2           PRUEBANET        3
# 3       HACETEGALICIA        4

# %% [markdown]
# ## Load page

# %%
page = pd.read_csv('./data/PAGE.csv')
page.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1835 entries, 0 to 1834
# Data columns (total 2 columns):
# PAGE_descripcion    1835 non-null object
# PAGE                1835 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 28.8+ KB

# %%
page.head()
# Out:
#         PAGE_descripcion  PAGE
# 0          WEB : EMINENT     1
# 1                 /LOGIN     2
# 2                /INICIO     3
# 3   /CUENTAS/MIS-CUENTAS     4
# 4  /ERROR/SESIONEXPIRADA     5

# %% [markdown]
# ## Load Conversiones

# %%
conversiones = pd.read_csv('./data/conversiones.csv')
conversiones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1738 entries, 0 to 1737
# Data columns (total 3 columns):
# mes        1738 non-null float64
# anio       1738 non-null float64
# USER_ID    1738 non-null float64
# dtypes: float64(3)
# memory usage: 40.8 KB

# %%
conversiones.head()
# Out:
#     mes    anio  USER_ID
# 0   7.0  2018.0   1410.0
# 1   8.0  2018.0  10755.0
# 2   8.0  2018.0   8270.0
# 3  10.0  2018.0   7558.0
# 4   9.0  2018.0  10731.0

# %% [markdown]
# ## Load Device Data

# %% [markdown]
#     - Datos de los dispositivos asociados a los usuarios

# %%
device_data = pd.read_csv('./data/device_data.csv')
device_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2871406 entries, 0 to 2871405
# Data columns (total 4 columns):
# FEC_EVENT           object
# CONNECTION_SPEED    int64
# IS_MOBILE_DEVICE    int64
# USER_ID             float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 87.6+ MB

# %%
device_data.tail()
# Out:
#                    FEC_EVENT  CONNECTION_SPEED  IS_MOBILE_DEVICE  USER_ID
# 2871401  2018-02-11 14:01:13                 1                 1  10935.0
# 2871402  2018-11-20 15:19:06                 1                 1  10935.0
# 2871403  2018-02-18 21:12:25                 1                 1  10935.0
# 2871404  2018-03-25 20:44:33                 1                 1  10935.0
# 2871405  2018-10-23 08:32:09                 1                 1  10935.0

# %% [markdown]
# ## Load pages view

# %% [markdown]
#     - Los datos de navegación de 2018

# %%
page_views = pd.read_csv('./data/pageviews.csv', header=None, chunksize=10000)
'''
i=0
for chunk in page_views:
    i+=1
print("Cantidad total: ",i) 
'''
# Out:
# '\ni=0\nfor chunk in page_views:\n    i+=1\nprint("Cantidad total: ",i) \n'

# %%
page_views = pd.read_csv('./data/pageviews.csv', chunksize=10000, iterator=True)

# %%
page_views.get_chunk(100)
# Out:
#                FEC_EVENT  PAGE  CONTENT_CATEGORY  CONTENT_CATEGORY_TOP  \
# 5    2018-03-30 07:41:42     2                 2                     2
# 6    2018-03-30 07:42:01     3                 2                     2
# 7    2018-03-30 07:42:05     4                 2                     2
# 8    2018-03-30 07:43:43     3                 2                     2
# 9    2018-03-30 07:44:14     6                 2                     2
# 10   2018-03-30 07:44:37     7                 2                     2
# 11   2018-03-30 07:44:58     2                 2                     2
# 12   2018-02-18 13:26:45     1                 1                     1
# 13   2018-02-05 14:39:37     8                 3                     3
# 14   2018-03-08 10:51:34     2                 2                     2
# 15   2018-03-08 10:51:37     9                 4                     2
# 16   2018-03-08 10:52:05    10                 4                     2
# ...
