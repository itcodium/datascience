# %% [markdown]
# # Distribucion uniforme

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=1
b=100
n=5000
data=np.random.uniform(a,b,n)

# %%
# %matplotlib inline
plt.hist(data)
# Out:
# (array([495., 482., 519., 493., 502., 488., 480., 521., 493., 527.]),
#  array([ 1.01606036, 10.90927527, 20.80249017, 30.69570508, 40.58891998,
#         50.48213488, 60.37534979, 70.26856469, 80.1617796 , 90.0549945 ,
#         99.9482094 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Distribucion Normal

# %%
data=np.random.randn(1000000)

# %%
x=range(1,1000001)
plt.plot(x,sorted(data))

# %%
plt.hist(data)
# Out:
# (array([1.58000e+02, 4.20100e+03, 4.43540e+04, 1.97168e+05, 3.64404e+05,
#         2.83548e+05, 9.28440e+04, 1.26100e+04, 6.97000e+02, 1.60000e+01]),
#  array([-4.55778986, -3.59012647, -2.62246308, -1.6547997 , -0.68713631,
#          0.28052708,  1.24819047,  2.21585385,  3.18351724,  4.15118063,
#          5.11884401]),
#  <a list of 10 Patch objects>)

# %%
mu=5.5
sd=2.5
data=5.5+2.5*np.random.randn(10000)
plt.hist(data)
# Out:
# (array([   6.,   65.,  454., 1537., 2836., 2944., 1589.,  499.,   64.,
#            6.]),
#  array([-4.54118519, -2.52906063, -0.51693607,  1.4951885 ,  3.50731306,
#          5.51943763,  7.53156219,  9.54368675, 11.55581132, 13.56793588,
#         15.58006044]),
#  <a list of 10 Patch objects>)

# %%
data=np.random.randn(2,4)
data
# Out:
# array([[ 0.97505519, -0.44496563, -0.80684445,  0.43456539],
#        [-1.81209203, -1.74404549, -0.02982074,  0.40840945]])

# %% [markdown]
# # Simulacion de Montecarlo

# %%
pi_avg=0
n=10000
pi_value_list=[]
for i in range(100):
    value=0
    x=np.random.uniform(0,1,n).tolist()
    y=np.random.uniform(0,1,n).tolist()
    for j in range(n):
        z=z=np.sqrt((x[j]*x[j])+(y[j]*y[j]))
        if z<=1:
            value+=1
    float_value=float(value)
    pi_value=float_value *4/n
    pi_value_list.append(pi_value)
pi_avg+=pi_value

pi=pi_avg/100
print(pi)
plt.plot(pi_value_list)
# Out:
# 0.031516

# %% [markdown]
# # Dummy DataSets

# %%
data=pd.DataFrame(
 { 'A':np.random.randn(10),
   'B': 1.5+2.5*np.random.randn(10),
   'C':np.random.uniform(10)
 }
)

# %%
data.describe()
# Out:
#                A          B         C
# count  10.000000  10.000000  10.00000
# mean    0.250553   2.750763   4.59284
# std     0.835280   2.869664   0.00000
# min    -1.175414  -2.081647   4.59284
# 25%     0.001817   0.971078   4.59284
# 50%     0.173238   2.936781   4.59284
# 75%     0.791476   4.583410   4.59284
# max     1.404037   7.164210   4.59284

# %%
plt.hist(data["A"])
# Out:
# (array([1., 1., 0., 0., 3., 1., 1., 0., 1., 2.]),
#  array([-1.17541394, -0.91746883, -0.65952372, -0.40157861, -0.14363351,
#          0.1143116 ,  0.37225671,  0.63020182,  0.88814692,  1.14609203,
#          1.40403714]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data["B"])
# Out:
# (array([1., 1., 1., 0., 2., 0., 2., 1., 1., 1.]),
#  array([-2.08164687, -1.15706119, -0.23247551,  0.69211017,  1.61669586,
#          2.54128154,  3.46586722,  4.3904529 ,  5.31503858,  6.23962427,
#          7.16420995]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data["C"])
# Out:
# (array([ 0.,  0.,  0.,  0.,  0., 10.,  0.,  0.,  0.,  0.]),
#  array([4.09283971, 4.19283971, 4.29283971, 4.39283971, 4.49283971,
#         4.59283971, 4.69283971, 4.79283971, 4.89283971, 4.99283971,
#         5.09283971]),
#  <a list of 10 Patch objects>)

# %%
path_root="C:/Users/MYEQ/Documents/Itcodium.git/datascience/Datasets/"
path=path_root+"customer-churn-model/Customer Churn Model.txt"

data=pd.read_csv(path)
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 0       16.78       244.7           91         11.01       10.0           3
# 1       16.62       254.4          103         11.45       13.7           3
# 2       10.30       162.6          104          7.32       12.2           5
# 3        5.26       196.9           89          8.86        6.6           7
# 4       12.61       186.9          121          8.41       10.1           3
#
#    Intl Charge  CustServ Calls  Churn?
# 0         2.70               1  False.
# 1         3.70               1  False.
# 2         3.29               0  False.
# 3         1.78               2  False.
# 4         2.73               3  False.
#
# [5 rows x 21 columns]

# %%
columns_name=data.columns.values.tolist()
a=len(columns_name)
new_data=pd.DataFrame({
    'Column Name':columns_name,
    'A':np.random.randn(a),
    'B':np.random.uniform(0,1,a)
    
},index=range(0,0+a))
new_data
# Out:
#        Column Name         A         B
# 0            State  0.364822  0.535810
# 1   Account Length -0.322964  0.790085
# 2        Area Code -0.186373  0.608133
# 3            Phone  2.874840  0.619853
# 4       Int'l Plan  1.229354  0.915556
# 5       VMail Plan -0.434321  0.227227
# 6    VMail Message  0.829745  0.325709
# 7         Day Mins -0.168976  0.174033
# 8        Day Calls  0.277858  0.081535
# 9       Day Charge  2.347686  0.137267
# 10        Eve Mins  1.730260  0.288704
# 11       Eve Calls  1.077300  0.157512
# 12      Eve Charge -0.432020  0.354950
# 13      Night Mins  1.304717  0.799959
# 14     Night Calls -1.775031  0.013008
# 15    Night Charge  1.037246  0.426050
# 16       Intl Mins  1.207144  0.800336
# 17      Intl Calls -2.051571  0.984638
# 18     Intl Charge  0.519066  0.247115
# 19  CustServ Calls -1.204186  0.696368
# 20          Churn?  0.864999  0.664789
