# %%
import pandas as pd
path_root="C:/Users/MYEQ/Documents/Itcodium.git/datascience/Datasets/"
path=path_root+"customer-churn-model/Customer Churn Model.txt"

# %%
data=pd.read_csv(path)
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %% [markdown]
# # Crear un subconjunto de datos

# %%
account_length=data["Account Length"]
account_length.head()
# Out:
# 0    128
# 1    107
# 2    137
# 3     84
# 4     75
# Name: Account Length, dtype: int64

# %%
type(account_length)
# Out:
# pandas.core.series.Series

# %%
subset=data[["State","Account Length","Phone","Eve Charge"]]
subset.head()
# Out:
#   State  Account Length     Phone  Eve Charge
# 0    KS             128  382-4657       16.78
# 1    OH             107  371-7191       16.62
# 2    NJ             137  358-1921       10.30
# 3    OH              84  375-9999        5.26
# 4    OK              75  330-6626       12.61

# %%
type(subset)
# Out:
# pandas.core.frame.DataFrame

# %%
desired_columns=["State","Account Length","Phone","Eve Charge"]
subset=data[desired_columns]
subset.head()
# Out:
#   State  Account Length     Phone  Eve Charge
# 0    KS             128  382-4657       16.78
# 1    OH             107  371-7191       16.62
# 2    NJ             137  358-1921       10.30
# 3    OH              84  375-9999        5.26
# 4    OK              75  330-6626       12.61

# %%
desired_columns=["State","Account Length","Phone","Eve Charge","Int'l Plan",'VMail Message','Churn?']
all_columns_list=data.columns.values.tolist()
all_columns_list
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
sublist=[x for x in all_columns_list if x not in desired_columns]
sublist
# Out:
# ['Area Code',
#  'VMail Plan',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls']

# %%
subset=data[sublist]
subset.head()
# Out:
#    Area Code VMail Plan  Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# 0        415        yes     265.1        110       45.07     197.4         99
# 1        415        yes     161.6        123       27.47     195.5        103
# 2        415         no     243.4        114       41.38     121.2        110
# 3        408         no     299.4         71       50.90      61.9         88
# 4        415         no     166.7        113       28.34     148.3        122
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    CustServ Calls
# ...

# %%
data[2:5]
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 2       10.30       162.6          104          7.32       12.2           5
# 3        5.26       196.9           89          8.86        6.6           7
# 4       12.61       186.9          121          8.41       10.1           3
#
#    Intl Charge  CustServ Calls  Churn?
# 2         3.29               0  False.
# ...

# %%
data1=data[(data["Day Charge"]>56) | (data["State"]=='NY')]
data1
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15      NY             161        415  351-7269         no         no
# 77      NY             144        408  360-1171         no         no
# 136     NY              75        415  374-8525         no        yes
# 156     OH              83        415  370-9116         no         no
# 182     NY              67        408  405-2888         no        yes
# 186     NY             106        408  422-1471         no         no
# 365     CO             154        415  343-5709         no         no
# 373     NY              32        415  364-3567         no         no
# 530     NY              47        415  391-1348         no        yes
# 539     NY              59        408  415-4609         no         no
# 551     NY             157        415  421-1189         no         no
# 597     NY              39        408  356-1889         no         no
# ...

# %%
subset_first50=data[["Account Length","Day Mins","Night Mins"]][:50]
subset_first50.head()
# Out:
#    Account Length  Day Mins  Night Mins
# 0             128     265.1       244.7
# 1             107     161.6       254.4
# 2             137     243.4       162.6
# 3              84     299.4       196.9
# 4              75     166.7       186.9

# %%
subset_first50[:10]
# Out:
#    Account Length  Day Mins  Night Mins
# 0             128     265.1       244.7
# 1             107     161.6       254.4
# 2             137     243.4       162.6
# 3              84     299.4       196.9
# 4              75     166.7       186.9
# 5             118     223.4       203.9
# 6             121     218.2       212.6
# 7             147     157.0       211.8
# 8             117     184.5       215.8
# 9             141     258.6       326.4

# %%
data.iloc[1:10,3:6] #filas 1 a 10 y Columnas 3 a 6
# Out:
#       Phone Int'l Plan VMail Plan
# 1  371-7191         no        yes
# 2  358-1921         no         no
# 3  375-9999        yes         no
# 4  330-6626        yes         no
# 5  391-8027        yes         no
# 6  355-9993         no        yes
# 7  329-9001        yes         no
# 8  335-4719         no         no
# 9  330-8173        yes        yes

# %%
# todas filas y Columnas 3 a 6
data.iloc[:,3:6][:5]
# Out:
#       Phone Int'l Plan VMail Plan
# 0  382-4657         no        yes
# 1  371-7191         no        yes
# 2  358-1921         no         no
# 3  375-9999        yes         no
# 4  330-6626        yes         no

# %%
data.iloc[3:6,[1,2,3]][:5]
# Out:
#    Account Length  Area Code     Phone
# 3              84        408  375-9999
# 4              75        415  330-6626
# 5             118        510  391-8027

# %%
data.loc[3:6,["Account Length","Day Mins","Night Mins"]][:5]
# Out:
#    Account Length  Day Mins  Night Mins
# 3              84     299.4       196.9
# 4              75     166.7       186.9
# 5             118     223.4       203.9
# 6             121     218.2       212.6

# %%
data["Total Mins"]= data["Day Mins"]+ data["Night Mins"]+ data["Eve Mins"]
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge     ...      Eve Charge  \
# 0             25     265.1        110       45.07     ...           16.78
# 1             26     161.6        123       27.47     ...           16.62
# 2              0     243.4        114       41.38     ...           10.30
# 3              0     299.4         71       50.90     ...            5.26
# 4              0     166.7        113       28.34     ...           12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...
